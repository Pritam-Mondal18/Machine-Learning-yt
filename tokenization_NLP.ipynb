# %% [markdown]
# <a href="https://colab.research.google.com/github/Pritam-Mondal18/Machine-Learning-yt/blob/main/tokenization_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# word tokenization using split function
text = "... that the Mortimer War Memorial (pictured) was erected three years after the end of the First World War, but a plaque honouring those who died in the Second World War was not added until 1999?"
print(text.split())
# Out:
# ['...', 'that', 'the', 'Mortimer', 'War', 'Memorial', '(pictured)', 'was', 'erected', 'three', 'years', 'after', 'the', 'end', 'of', 'the', 'First', 'World', 'War,', 'but', 'a', 'plaque', 'honouring', 'those', 'who', 'died', 'in', 'the', 'Second', 'World', 'War', 'was', 'not', 'added', 'until', '1999?']

# %%
# Sentance tokenization using split function
text = "... that the Mortimer War Memorial (pictured) was erected three years after the end of the First World War, but a plaque honouring those who died in the Second World War was not added until 1999?"
print(text.split('.'))
# Out:
# ['', '', '', ' that the Mortimer War Memorial (pictured) was erected three years after the end of the First World War, but a plaque honouring those who died in the Second World War was not added until 1999?']

# %%
# tokenization using Regular Expressition
import re
text = "... that the Mortimer War Memorial (pictured) was erected three years after the end of the First World War, but a plaque honouring those who died in the Second World War was not added until 1999?"
tokens = re.findall(r"[\w']+", text)
print(tokens)
# Out:
# ['that', 'the', 'Mortimer', 'War', 'Memorial', 'pictured', 'was', 'erected', 'three', 'years', 'after', 'the', 'end', 'of', 'the', 'First', 'World', 'War', 'but', 'a', 'plaque', 'honouring', 'those', 'who', 'died', 'in', 'the', 'Second', 'World', 'War', 'was', 'not', 'added', 'until', '1999']

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab') # Download the missing resource
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
# tokenization using NLTK
import nltk
from nltk.tokenize import word_tokenize,sent_tokenize
text = "... that the Mortimer War Memorial (pictured). It was erected three years after the end of the First World War. but a plaque honouring those who died in the Second World War was not added until 1999?"
sent_tokenize(text)
# Out:
# ['... that the Mortimer War Memorial (pictured).',
#  'It was erected three years after the end of the First World War.',
#  'but a plaque honouring those who died in the Second World War was not added until 1999?']

# %%
# tokenization using spacy
import spacy
nlp = spacy.load('en_core_web_sm')
text = "... that the Mortimer War Memorial (pictured). It was erected three years after the end of the First World War. but a plaque honouring those who died in the Second World War was not added until 1999?"
doc = nlp(text)
tokens = [token.text for token in doc]
print(tokens)
# Out:
# ['...', 'that', 'the', 'Mortimer', 'War', 'Memorial', '(', 'pictured', ')', '.', 'It', 'was', 'erected', 'three', 'years', 'after', 'the', 'end', 'of', 'the', 'First', 'World', 'War', '.', 'but', 'a', 'plaque', 'honouring', 'those', 'who', 'died', 'in', 'the', 'Second', 'World', 'War', 'was', 'not', 'added', 'until', '1999', '?']

# %%
# Stemming
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
def stem_words(text):
    return " ".join([ps.stem(word) for word in text.split()])
sample = "walk walks walking walked"
stem_words(sample)
# Out:
# 'walk walk walk walk'

# %%
# Lemmatization
import nltk
nltk.download('wordnet') # Download the wordnet corpus
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()
sentence = "He is running and eating at the same time.He has bad habit of swimming after playing long hours in the Sun."
punctuations = '?:!.,;'
sentence_words = nltk.word_tokenize(sentence)
for word in sentence_words:
  if word in punctuations:
    sentence_words.remove(word)
sentence_words
print("{0:20}{1:20}".format("Word","Lemma"))
for word in sentence_words:
  print("{0:20}{1:20}".format(word,wordnet_lemmatizer.lemmatize(word,pos='v')))
# Out:
# Word                Lemma
# He                  He
# is                  be
# running             run
# and                 and
# eating              eat
# at                  at
# the                 the
# same                same
# time.He             time.He
# has                 have
# bad                 bad
# habit               habit
# of                  of
# swimming            swim
# after               after
# playing             play
# long                long
# hours               hours
# in                  in
# the                 the
# Sun                 Sun
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
