# %% [markdown]
# <a href="https://colab.research.google.com/github/Pritam-Mondal18/Machine-Learning-yt/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Matplotlib***
#
# ### 1) Matplotlib Basics
# ### 2) Subplots in Matplotlib
# ### 3) Object Oriented way
# ### 4) Types of Plots
# ### 5) Saving Plots
# ### 6) Working with Images
# ### 7) Optional Design

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1) Matplotlib Basics

# %%
x = np.linspace(0,5,11) # Linear Spacing(linspace); [I want 11 elements, between 0-5]
x
y = x**2
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y)
plt.title("Hello")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
# Out:
# Text(0, 0.5, 'Y-axis')

# %% [markdown]
# ## 2) Subplots in Matplotlib

# %%
plt.subplot(2,2,1)
plt.plot(x,y,'r') # 'r' --> 'red"
plt.subplot(2,2,2)
plt.plot(y,x,'b') # 'b' --> 'blue'
plt.subplot(2,2,3)
plt.plot(x,x,'g') # 'g' --> 'green'
plt.subplot(2,2,4)
plt.plot(y,y,'y') # 'y' --> 'yellow'

# %% [markdown]
# ## 3) Object Oriented way

# %% [markdown]
# ## Matplotlib allows the aspect ratio, DPI and figure size to be specified when the Figure object is created. You can use the figsize and dpi keyword arguments.
#
# ## figsize is a tuple of the width and height of the figure in inches dpi is the dots-per-inch (pixel per inch).

# %%
fig = plt.figure(figsize=(20,8), dpi=100) # by default dpi(dots-per-inches) = 100
axis1 = fig.add_axes([0.1,0.1,0.8,0.8])
axis1.plot(x,y)
axis2 = fig.add_axes([0.3,0.4,0.2,0.2])
axis2.plot(x,y)

# %% [markdown]
# ## 4) Types of Plots

# %%
plt.scatter(x,y)

# %%
plt.hist(x,y)
# Out:
# (array([1., 1., 3., 3., 3., 0., 0., 0., 0., 0.]),
#  array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#         20.25, 25.  ]),
#  <BarContainer object of 10 artists>)
