# %% [markdown]
# <a href="https://colab.research.google.com/github/Pritam-Mondal18/Machine-Learning-yt/blob/main/Pandas_phase5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pivote Table

# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    401     68   John  January      Q1
# 1  2023-01-02       B   West    933     90   Mary  January      Q1
# 2  2023-01-03       C  North    682     94    Bob  January      Q1
# 3  2023-01-04       D  South    480     78  Alice  January      Q1
# 4  2023-01-05       A   East    591     71   John  January      Q1
# 5  2023-01-06       B   West    532     25   Mary  January      Q1
# 6  2023-01-07       C  North    533     11    Bob  January      Q1
# 7  2023-01-08       D  South    244     34  Alice  January      Q1
# 8  2023-01-09       A   East    278     54   John  January      Q1
# 9  2023-01-10       B   West    639     23   Mary  January      Q1
# 10 2023-01-11       C  North    634     78    Bob  January      Q1
# 11 2023-01-12       D  South    641     99  Alice  January      Q1
# 12 2023-01-13       A   East    634     43   John  January      Q1
# 13 2023-01-14       B   West    805     13   Mary  January      Q1
# 14 2023-01-15       C  North    665     32    Bob  January      Q1
# 15 2023-01-16       D  South    865     70  Alice  January      Q1
# 16 2023-01-17       A   East    428     23   John  January      Q1
# 17 2023-01-18       B   West    889     12   Mary  January      Q1
# 18 2023-01-19       C  North    105     70    Bob  January      Q1
# 19 2023-01-20       D  South    176     73  Alice  January      Q1

# %%
pd.pivot_table(df, values="Sales",index='Region',columns='Product',aggfunc='median')
# Out:
# Product      A      B      C      D
# Region
# East     428.0    NaN    NaN    NaN
# North      NaN    NaN  634.0    NaN
# South      NaN    NaN    NaN  480.0
# West       NaN  805.0    NaN    NaN

# %%
pivote2 = pd.pivot_table(df,values=['Sales','Units'],index='Region', columns='Product' )
pivote2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     466.4    NaN    NaN    NaN  51.8   NaN   NaN   NaN
# North      NaN    NaN  523.8    NaN   NaN   NaN  57.0   NaN
# South      NaN    NaN    NaN  481.2   NaN   NaN   NaN  70.8
# West       NaN  759.6    NaN    NaN   NaN  32.6   NaN   NaN

# %% [markdown]
# # Cross Tabs
# #### Its used for counting purpose

# %%
pd.crosstab(df['Region'],df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
