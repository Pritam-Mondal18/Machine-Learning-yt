# %% [markdown]
# <a href="https://colab.research.google.com/github/Pritam-Mondal18/Machine-Learning-yt/blob/main/Pandas_phase1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # [#] Pandas
# ## Use case of pandas
# ### 1. Data Cleaning
# ### 2. Data Analysis
# ### 3. Data Transformation
# ### 4. Data Visualization (Basic Level)
# ### 5. Data Aggregation
# ### 6. File Handling
# ### 7. Data Filtering & Selection
# ### 8. Time Series Analysis

# %% [markdown]
# # Pandas Series
#
# A series is a one-dimantional labeled array capable of holding any data type.The axis labels are collectivly called the index.

# %% [markdown]
# ## Creating Series
# ### There are multiple ways to create a pandas series:

# %%
import numpy as np
import pandas as pd

# %%
labels = ['a','b','c'] # labels are nothing but index
my_list = [10,20,30]
arr = np.array([10,20,30,40])
d = {1:20, 2:30, 3:40}

# %%
# Series using list
pd.Series(my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
# change the series index/labels
pd.Series(my_list, index = labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
# Create Series using Array
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
# create Series using Dictinary
# We use by default index which are maintioned in the dictinaty
pd.Series(d)
# Out:
# 1    20
# 2    30
# 3    40
# dtype: int64

# %% [markdown]
# # [#] DataFrame : DataFrame is nothig but it's a combination of Series.
# ## 1. Creating a DataFrame
# ## 2. Selection and Indexing a coloumns
# ## 3. Creating a new column
# ## 4. Removing column
# ## 5. Selecting Rows
# ## 6. Selecting Subsets of Rows and Columns
# ## 7. Conditional Section

# %% [markdown]
# # {####}For the Creation of Data Frame we can create it only by the dictinory and list.

# %%
# Creating a DataFrame using Dictinory
data = {
    'Name' : ['John','Anna','Peter','Linda'],
    'Age' : [28.34,29,42],
    'City' : ['New York', 'Paris','Berlin','London'],
    'Salary': [65000,70000,62000,85000]
}

# %%
data = {
    'Name' : ['John','Anna','Peter','Linda'],
    'Age' : [28,29,42,35], # Added a fourth age to match the length of other lists
    'City' : ['New York', 'Paris','Berlin','London'],
    'Salary': [65000,70000,62000,85000]
}
df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   29     Paris   70000
# 2  Peter   42    Berlin   62000
# 3  Linda   35    London   85000

# %%
# Creating a DataFrame using List
data_list = [
    ['John',28,'New York',65000],
    ['Anna',29,'Paris',70000],
    ['Peter',42,'Berlin',62000],
    ['Linda',35,'London',85000]
]

# %%
df2 = pd.DataFrame(data_list)
col = ['Name','Age','City','Salary']
df3 = pd.DataFrame(data_list,columns=col)
print(df3)
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   29     Paris   70000
# 2  Peter   42    Berlin   62000
# 3  Linda   35    London   85000

# %% [markdown]
# # Selection and indexing of colums

# %%
df3[['Name',
    'Age']]
# Out:
#     Name  Age
# 0   John   28
# 1   Anna   29
# 2  Peter   42
# 3  Linda   35

# %% [markdown]
# # Creating a new coloum

# %%
df3['Designation'] = ['Doc','Eng','Doc','Eng']
df3
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000         Doc
# 1   Anna   29     Paris   70000         Eng
# 2  Peter   42    Berlin   62000         Doc
# 3  Linda   35    London   85000         Eng

# %%
df3['Designation'] = ['Doc','Eng','Doc','Eng']
print(df3)
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000         Doc
# 1   Anna   29     Paris   70000         Eng
# 2  Peter   42    Berlin   62000         Doc
# 3  Linda   35    London   85000         Eng

# %% [markdown]
# # Removing Coloumn

# %%
df3.drop('Designation',axis=1)
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   29     Paris   70000
# 2  Peter   42    Berlin   62000
# 3  Linda   35    London   85000

# %% [markdown]
# ## when we use "inplace=True" that means that particular coloumn will be remove parmanent.

# %%
df3.drop('Designation',axis=1, inplace=True)
df3
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   29     Paris   70000
# 2  Peter   42    Berlin   62000
# 3  Linda   35    London   85000

# %% [markdown]
# # Removing Row

# %%
df3.drop(0,axis=0)
df3
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   29     Paris   70000
# 2  Peter   42    Berlin   62000
# 3  Linda   35    London   85000

# %%
# Select the specific row
df3.loc[1] # loc=location
# Out:
# Name       Anna
# Age          29
# City      Paris
# Salary    70000
# Name: 1, dtype: object

# %%
# for multiple rows
df3.loc[[1,3]]
# Out:
#     Name  Age    City  Salary
# 1   Anna   29   Paris   70000
# 3  Linda   35  London   85000

# %%
df3.iloc[3] # iloc ==>> index locations  28:20
# Out:
# Name       Linda
# Age           35
# City      London
# Salary     85000
# Name: 3, dtype: object

# %% [markdown]
# # Selecting Subsets of Rows and Columns

# %%
df3.iloc[[0,1]][['City','Salary']]
# Out:
#        City  Salary
# 0  New York   65000
# 1     Paris   70000

# %%
df3.iloc[[2,3]][['Name','Age']] # -->> df3.iloc[[row1,row2]][["col1","col2"]]
# Out:
#     Name  Age
# 2  Peter   42
# 3  Linda   35

# %% [markdown]
# # Conditional Statement

# %%
df3
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   29     Paris   70000
# 2  Peter   42    Berlin   62000
# 3  Linda   35    London   85000

# %% [markdown]
# ### I want to see only these people who are avobe the age 30.

# %%
# df3[df3["Age"]>30]
# df3
df3 = df3[df3["Age"] > 30]
df3
# Out:
#     Name  Age    City  Salary
# 2  Peter   42  Berlin   62000
# 3  Linda   35  London   85000

# %% [markdown]
# I want to see only these people who are avobe the age 30 and live in Paris.

# %%
# df3 [( df3 ["Age"] < 30)]
df3[(df3["Age"] > 20) & (df3["City"] == 'Paris')]
df3
# Out:
#     Name  Age    City  Salary
# 2  Peter   42  Berlin   62000
# 3  Linda   35  London   85000
